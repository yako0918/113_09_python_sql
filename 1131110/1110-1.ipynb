# %%
pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/8.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.6 MB 3.4 MB/s eta 0:00:03
#    --------------------- ------------------ 4.7/8.6 MB 13.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.6/8.6 MB 20.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/658.1 kB ? eta -:--:--
#    --------------------------------------- 658.1/658.1 kB 26.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------------- -------------------------- 4.2/12.6 MB 20.9 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 21.5 MB/s eta 0:00:01
#    ---------------------------------------  12.3/12.6 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 17.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
# ...

# %%
pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/939.5 kB ? eta -:--:--
#      ----------- ---------------------------- 262.1/939.5 kB ? eta -:--:--
#      -------------------------------------- 939.5/939.5 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 9.7 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ---------------------------------------- 3.1/3.1 MB 26.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
# ...
